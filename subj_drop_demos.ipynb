# %% [markdown]
# # Subject dropping

# %% [markdown]
# - from df exclude all subs whose id is not in that tsv file
# - perform t tests and check for differences
# - plot what you found?

# %%
import numpy as np
import pandas as pd
import os
import glob
import json
from scipy.stats import ttest_ind
from scipy import stats
import pingouin as pg
import matplotlib.pyplot as plt
import seaborn as sns

# %%
all_subj = '/home/gabridele/Desktop/preproc_psych/all_subj.tsv'
subj_keep_file = '/home/gabridele/Desktop/preproc_psych/subj_keep.tsv'
df_fd_file = '/home/gabridele/Desktop/preproc_psych/fd_values_scap-fMRI.xlsx'
sub_list2_file = '/home/gabridele/Desktop/preproc_psych/preproc_sub_list2.xlsx'
sub_list3_file = '/home/gabridele/Desktop/preproc_psych/preproc_sub_list3.xlsx'

# %% [markdown]
# Get demos and wais

# %%
participants_df = pd.read_csv(all_subj, delimiter='\t')
participants_file = "/home/gabridele/Desktop/psych_dataset/participants.tsv"

df_participants = pd.read_csv(participants_file, sep='\t', header=0)

# Read demographics file
demographics_file = '/home/gabridele/Desktop/psych_dataset/phenotype/demographics.tsv'
df_demo = pd.read_csv(demographics_file, sep='\t', header=0)

# Read WAIS file
wais_file = '/home/gabridele/Desktop/psych_dataset/phenotype/wais.tsv'
df_wais = pd.read_csv(wais_file, sep='\t', header=0)

#preallocate
age = np.zeros((len(df_participants.index)))
sex = age.copy()
site = age.copy()
edu_years = age.copy()
hand = age.copy()
wais_mr = age.copy() 
wais_lns = age.copy()
wais_voc = age.copy()

for subidx,subj in enumerate(df_participants["participant_id"]):
    idx = df_participants.participant_id==subj
    
    #age
    age[subidx] = np.int64(df_participants.age[idx].values[0])
    
    #sex
    _sex = df_participants.gender[idx].values
    if _sex == 'F':
        sex[subidx] = 0

    elif _sex == 'M':
        sex[subidx] = 1

    #site
    data = []
    file = f'/home/gabridele/Desktop/psych_dataset/{subj}/func/{subj}_task-scap_bold.json'
    try:
        with open(file) as json_data:
            data.append(json.load(json_data))

        if data[0]['SoftwareVersions'] == 'syngo MR B15':
            site[subidx] = 1
        elif data[0]['SoftwareVersions'] == 'syngo MR B17':
            site[subidx] = 0
    except FileNotFoundError:
        print(f'{subj} doesn\'t have scap task')
        

    # education (how many years of schooling complete?)
    edu_years[subidx] = np.int64(df_demo.school_yrs[idx].values[0])
    
    #
    #hand = 
    # wais
    wais_mr[subidx] = np.int64(df_wais.mr_totalraw[idx].values[0]) 
    wais_lns[subidx] = np.int64(df_wais.lns_totalraw[idx].values[0])
    wais_voc[subidx] = np.int64(df_wais.voc_totalraw[idx].values[0])
    
# put the data in the df
labels = ['age','sex','site','edu_years','wais_mr','wais_lns','wais_voc']
demo_data = np.vstack((age,sex,site,edu_years,wais_mr,wais_lns,wais_voc)).T
demo_df = pd.DataFrame(data=demo_data,index=participants_df.index,columns=labels)
df = pd.concat([participants_df,demo_df],axis=1)
print(df)
# print average demos
print(df['diagnosis'].value_counts())
print(df.groupby('diagnosis')[['age', 'sex', 'site']].mean())
groups = ['CTRL', 'SCHZ', 'BPLR', 'ADHD']
df.to_excel('/home/gabridele/Desktop/preproc_psych/preproc_sub_list3.xlsx', index=True)
# Out:
# sub-10193 doesn't have scap task
# sub-10948 doesn't have scap task
# sub-11082 doesn't have scap task
# sub-70002 doesn't have scap task
#         Sub_ID diagnosis   reason Hearne base Hearne site control Notes   age  \
# 0    sub-10159   CONTROL      NaN   sub-10159                 NaN   NaN  30.0
# 1    sub-10171   CONTROL      NaN   sub-10171                 NaN   NaN  24.0
# 2    sub-10189   CONTROL      NaN   sub-10189           sub-10189   NaN  49.0
# 3    sub-10193   CONTROL  no scap         NaN                 NaN   NaN  40.0
# 4    sub-10206   CONTROL      NaN         NaN                 NaN   NaN  21.0
# ..         ...       ...      ...         ...                 ...   ...   ...
# 267  sub-70079      ADHD      NaN   sub-70079           sub-70079   NaN  21.0
# 268  sub-70080      ADHD      NaN   sub-70080           sub-70080   NaN  48.0
# 269  sub-70081      ADHD      NaN   sub-70081           sub-70081   NaN  50.0
# 270  sub-70083      ADHD      NaN   sub-70083           sub-70083   NaN  46.0
# 271  sub-70086      ADHD      NaN   sub-70086           sub-70086   NaN  48.0
#
#      sex  site  edu_years  wais_mr  wais_lns  wais_voc
# 0    0.0   1.0       16.0     21.0      19.0      49.0
# 1    1.0   1.0       16.0     23.0      28.0      53.0
# 2    1.0   1.0       16.0     22.0      18.0      48.0
# 3    1.0   0.0       12.0     17.0      20.0      30.0
# 4    1.0   1.0       13.0     20.0      14.0      35.0
# ..   ...   ...        ...      ...       ...       ...
# 267  1.0   0.0       15.0     16.0      22.0      52.0
# 268  1.0   0.0       13.0     17.0      20.0      51.0
# 269  1.0   0.0       12.0     18.0      22.0      42.0
# 270  0.0   0.0       16.0     19.0      17.0      29.0
# 271  1.0   0.0       14.0     19.0      21.0      56.0
#
# [272 rows x 13 columns]
# diagnosis
# CONTROL    130
# SCZ         50
# BIPOLAR     49
# ADHD        43
# Name: count, dtype: int64
#                  age       sex      site
# diagnosis
# ADHD       33.093023  0.488372  0.511628
# BIPOLAR    35.285714  0.571429  0.530612
# CONTROL    31.261538  0.523077  0.800000
# SCZ        36.460000  0.760000  0.500000

# %% [markdown]
# merge mean FD

# %%
participants_df = pd.read_csv(all_subj, delimiter='\t')

df_fd = pd.read_excel(df_fd_file)
sub_list3 = pd.read_excel(sub_list3_file)

df_fd.columns = ['Sub_ID'] + list(df_fd.columns[1:])

participants_dff = participants_df.merge(df_fd[['Sub_ID', 'mean']], on='Sub_ID', how='left')

participants_dff.rename(columns={'mean': 'mean_FD'}, inplace=True)

dff = participants_dff.merge(sub_list3[['Sub_ID', 'age','sex','site','edu_years','wais_mr','wais_lns','wais_voc']], on='Sub_ID', how='left')

dff.to_csv("/home/gabridele/Desktop/preproc_psych/subj_keeeeep.tsv", sep='\t', index=False)

# %%
print(dff)
# Out:
#         Sub_ID diagnosis   reason Hearne base Hearne site control Notes  \
# 0    sub-10159   CONTROL      NaN   sub-10159                 NaN   NaN
# 1    sub-10171   CONTROL      NaN   sub-10171                 NaN   NaN
# 2    sub-10189   CONTROL      NaN   sub-10189           sub-10189   NaN
# 3    sub-10193   CONTROL  no scap         NaN                 NaN   NaN
# 4    sub-10206   CONTROL      NaN         NaN                 NaN   NaN
# ..         ...       ...      ...         ...                 ...   ...
# 267  sub-70079      ADHD      NaN   sub-70079           sub-70079   NaN
# 268  sub-70080      ADHD      NaN   sub-70080           sub-70080   NaN
# 269  sub-70081      ADHD      NaN   sub-70081           sub-70081   NaN
# 270  sub-70083      ADHD      NaN   sub-70083           sub-70083   NaN
# 271  sub-70086      ADHD      NaN   sub-70086           sub-70086   NaN
#
#       mean_FD  age  sex  site  edu_years  wais_mr  wais_lns  wais_voc
# 0    0.177901   30    0     1         16       21        19        49
# 1    0.174510   24    1     1         16       23        28        53
# 2    0.142876   49    1     1         16       22        18        48
# 3         NaN   40    1     0         12       17        20        30
# 4    0.077702   21    1     1         13       20        14        35
# ..        ...  ...  ...   ...        ...      ...       ...       ...
# 267  0.176860   21    1     0         15       16        22        52
# 268  0.164081   48    1     0         13       17        20        51
# 269  0.095929   50    1     0         12       18        22        42
# 270  0.200959   46    0     0         16       19        17        29
# 271  0.164218   48    1     0         14       19        21        56
#
# [272 rows x 14 columns]

# %% [markdown]
# Exclude no dwi and no scap

# %%
dff = pd.read_csv("/home/gabridele/Desktop/preproc_psych/subj_keeeeep.tsv", sep='\t')
print(dff.columns)
a = (dff['reason'] != "ghost").values & (dff['reason'] != "no dwi").values & (dff['reason'] != "no scap").values & (dff['reason'] != "ghost, mean FD > 0.5").values & (dff['reason'] != "ghost, FD perc and mean > 0.5").values
b = ~a
exclude_subj = dff[a]

# Save the modified DataFrame to a new CSV file
exclude_subj.to_csv('/home/gabridele/Desktop/preproc_psych/subj_keep4.tsv', sep='\t', index=False)
# Out:
# Index(['Sub_ID', 'diagnosis', 'reason', 'Hearne base', 'Hearne site control',
#        'Notes', 'mean_FD', 'age', 'sex', 'site', 'edu_years', 'wais_mr',
#        'wais_lns', 'wais_voc'],
#       dtype='object')

# %%
print(np.count_nonzero(b))
print(np.unique(b))
print(exclude_subj['diagnosis'].value_counts())
# Out:
# 61
# [False  True]
# diagnosis
# CONTROL    106
# BIPOLAR     41
# ADHD        35
# SCZ         29
# Name: count, dtype: int64

# %% [markdown]
# do the merging now. create yet another df starting from exclude_subj and merge based on sub_id the fd valuez

# %%
df_fd = pd.read_excel(df_fd_file)


df_fd.columns = ['Sub_ID'] + list(df_fd.columns[1:])
all_fd_values = exclude_subj.drop('mean_FD', axis=1)
all_fd_values = all_fd_values.merge(df_fd[['Sub_ID', 'mean', 'std', 'min', '25%', '50%', '75%', 'max', '% > 0.2', '% > 0.5', 'Absolute > 0.2', 'Absolute > 0.5']], on='Sub_ID', how='left')

all_fd_values.rename(columns={'mean': 'mean_FD', 'std': 'std_FD', 'min': 'min_FD', 'max': 'max_FD', '% > 0.2': '% > 0.2_FD', '% > 0.5': '% > 0.5_FD', 'Absolute > 0.2': 'Absolute > 0.2_FD', 'Absolute > 0.5': 'Absolute > 0.5_FD'}, inplace=True)

all_fd_values.to_csv("/home/gabridele/Desktop/preproc_psych/all_fd_values.tsv", sep='\t', index=False)
print(all_fd_values.columns)
# Out:
# Index(['Sub_ID', 'diagnosis', 'reason', 'Hearne base', 'Hearne site control',
#        'Notes', 'age', 'sex', 'site', 'edu_years', 'wais_mr', 'wais_lns',
#        'wais_voc', 'mean_FD', 'std_FD', 'min_FD', '25%', '50%', '75%',
#        'max_FD', '% > 0.2_FD', '% > 0.5_FD', 'Absolute > 0.2_FD',
#        'Absolute > 0.5_FD'],
#       dtype='object')

# %% [markdown]
# Plotting FD

# %% [markdown]
# # RIFARE

# %%
# Read the transposed Excel file into a DataFrame
df = pd.read_csv("/home/gabridele/Desktop/preproc_psych/all_fd_values.tsv", sep='\t')

custom_labels = ["CTRL (N=106)", "SCZ (N=29)", "BIPOLAR (N=41)", "ADHD (N=35)"]

# Create a subplot layout with 3 rows and 2 columns
plt.figure(figsize=(12, 15))

# Boxplot for percentage of values > 0.2 by diagnosis
plt.subplot(3, 2, 1)
sns.boxplot(x="diagnosis", y="% > 0.2_FD", data=df, palette="Set3")
plt.title("Percentage of Values > 0.2 by Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("% Values > 0.2")
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels)

# Boxplot for percentage of values > 0.5 by diagnosis
plt.subplot(3, 2, 2)
sns.boxplot(x="diagnosis", y="% > 0.5_FD", data=df, palette="Set3")
plt.title("Percentage of Values > 0.5 by Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("% Values > 0.5")
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels)

# Boxplot for absolute count of values > 0.2 by diagnosis
plt.subplot(3, 2, 3)
sns.boxplot(x="diagnosis", y="Absolute > 0.2_FD", data=df, palette="Set3")
plt.title("Absolute Count of Values > 0.2 by Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("Absolute Count > 0.2")
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels)

# Boxplot for absolute count of values > 0.5 by diagnosis
plt.subplot(3, 2, 4)
sns.boxplot(x="diagnosis", y="Absolute > 0.5_FD", data=df, palette="Set3")
plt.title("Absolute Count of Values > 0.5 by Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("Absolute Count > 0.5")
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels)

# Boxplot for mean FD values by diagnosis
plt.subplot(3, 2, 5)
sns.boxplot(x="diagnosis", y="mean_FD", data=df, palette="Set3")
plt.title("Mean Framewise Displacement by Diagnosis")
plt.xlabel("Diagnosis")
plt.ylabel("Mean FD")
plt.xticks(ticks=range(len(custom_labels)), labels=custom_labels)

plt.suptitle("FD plots on SCAP task", fontsize=16)

# Adjust layout to prevent overlap
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
# Last exclusion: beyond FD threshold

# %%
subj_df = pd.read_csv("/home/gabridele/Desktop/preproc_psych/subj_keep4.tsv", sep='\t')

a = (subj_df['reason'] != "mean FD > 0.5").values
b = ~a
exclude_final = subj_df[a]

# Save the modified DataFrame to a new CSV file
exclude_final.to_csv('/home/gabridele/Desktop/preproc_psych/subj_final.tsv', sep='\t', index=False)

# %%
print(np.count_nonzero(b))
print(np.unique(b))
print(exclude_final['diagnosis'].value_counts())
print(exclude_final)
# Out:
# 61
# [False  True]
# diagnosis
# CONTROL    100
# BIPOLAR     40
# ADHD        34
# SCZ         27
# Name: count, dtype: int64
#         Sub_ID diagnosis reason Hearne base Hearne site control Notes  \
# 0    sub-10159   CONTROL    NaN   sub-10159                 NaN   NaN
# 1    sub-10171   CONTROL    NaN   sub-10171                 NaN   NaN
# 2    sub-10189   CONTROL    NaN   sub-10189           sub-10189   NaN
# 3    sub-10206   CONTROL    NaN         NaN                 NaN   NaN
# 4    sub-10217   CONTROL    NaN   sub-10217           sub-10217   NaN
# ..         ...       ...    ...         ...                 ...   ...
# 206  sub-70079      ADHD    NaN   sub-70079           sub-70079   NaN
# 207  sub-70080      ADHD    NaN   sub-70080           sub-70080   NaN
# 208  sub-70081      ADHD    NaN   sub-70081           sub-70081   NaN
# 209  sub-70083      ADHD    NaN   sub-70083           sub-70083   NaN
# 210  sub-70086      ADHD    NaN   sub-70086           sub-70086   NaN
#
#       mean_FD  age  sex  site  edu_years  wais_mr  wais_lns  wais_voc
# 0    0.177901   30    0     1         16       21        19        49
# 1    0.174510   24    1     1         16       23        28        53
# 2    0.142876   49    1     1         16       22        18        48
# 3    0.077702   21    1     1         13       20        14        35
# 4    0.064066   33    0     1         16       20        22        46
# ..        ...  ...  ...   ...        ...      ...       ...       ...
# 206  0.176860   21    1     0         15       16        22        52
# 207  0.164081   48    1     0         13       17        20        51
# 208  0.095929   50    1     0         12       18        22        42
# 209  0.200959   46    0     0         16       19        17        29
# 210  0.164218   48    1     0         14       19        21        56
#
# [201 rows x 14 columns]

# %% [markdown]
# Functions for stat testing

# %%
def all_groups_ttest(df, labels=['age','sex','site']):
    output = ""
    groups = df['diagnosis'].unique()
    for label in labels:
        output += f"t-test, Var={label}\n"
        for i, group1 in enumerate(groups):
            for group2 in groups[i+1:]:
                x = df[df['diagnosis'] == group1][label].values
                y = df[df['diagnosis'] == group2][label].values
                t, p = ttest_ind(x, y, equal_var=False)
                output += f"\tComparing {group1} vs {group2}:\n"
                output += f"\t  t = {t}\n"
                output += f"\t  p = {p}\n"
                
    output += "\nMeans:\n"
    output += str(df.groupby(['diagnosis'])[labels].mean()) + "\n"
    output += "\nStd:\n"
    output += str(df.groupby(['diagnosis'])[labels].std()) + "\n"

    return output

def all_groups_stats(df, labels=['age','sex','site']):
    output = ""
    groups = df['diagnosis'].unique()
    for label in labels:
        for i, group1 in enumerate(groups):
            for group2 in groups[i+1:]:
                if label == 'sex' or label == 'site':
                    output += f"Chi-square test, Var={label}\n"
                    new_df = df.loc[(df['diagnosis'] == group1) | (df['diagnosis'] == group2)]
                    expected, observed, stats = pg.chi2_independence(data=new_df, x=label, y='diagnosis')
                    output += f"\t Comparing {group1} vs {group2}:\n"
                    output += f"\t Chi2 = {np.round(stats.chi2[0], 3)}\n"
                    output += f"\t p = {np.round(stats.pval[0], 8)}\n"
                    output += f"\t Cramer's V = {np.round(stats.cramer[0], 8)}\n"
                else:
                    output += f"t-test, Var={label}\n"
                    x = df[df['diagnosis'] == group1][label].values
                    y = df[df['diagnosis'] == group2][label].values
                    t, p = ttest_ind(x, y, equal_var=False)
                    cohen_d = (abs(np.mean(x) - np.mean(y))) / np.sqrt(((len(x) - 1) * np.var(x, ddof=1) + (len(y) - 1) * np.var(y, ddof=1)) / (len(x) + len(y) - 2))                    
                    output += f"\t Comparing {group1} vs {group2}:\n"
                    output += f"\t  t = {t}\n"
                    output += f"\t  p = {p}\n"
                    output += f"\t  Cohen's d = {cohen_d:.8f}\n"

    output += "\nMeans:\n"
    output += str(df.groupby(['diagnosis'])[labels].mean()) + "\n"
    output += "\nStd:\n"
    output += str(df.groupby(['diagnosis'])[labels].std()) + "\n"

    return output

# %% [markdown]
# Stat testing

# %%
print(exclude_final.columns)
# Out:
# Index(['Sub_ID', 'diagnosis', 'reason', 'Hearne base', 'Hearne site control',
#        'Notes', 'mean_FD', 'age', 'sex', 'site', 'edu_years', 'wais_mr',
#        'wais_lns', 'wais_voc'],
#       dtype='object')

# %%
#table 
print(exclude_final['diagnosis'].value_counts())
labels = ['age','sex','site','mean_FD','edu_years','wais_mr','wais_lns','wais_voc']
groups = ['CTRL', 'SCZ', 'BPLR', 'ADHD']
#print(exclude_final.groupby(['diagnosis'])[labels].mean())
test_results = all_groups_stats(exclude_final, labels=labels)

txt_file_path = '/home/gabridele/Desktop/preproc_psych/final_list_tests.txt'

# Save the output to a text file
with open(txt_file_path, 'w') as txt_file:
    txt_file.write(test_results)
# Out:
# diagnosis
# CONTROL    103
# BIPOLAR     40
# ADHD        34
# SCZ         27
# Name: count, dtype: int64

# %%
print(test_results)
# Out:
# t-test, Var=age
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.4606197838759827
# 	  p = 0.018332359470566856
# t-test, Var=age
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.9315155450354025
# 	  p = 0.05750580657571162
# t-test, Var=age
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.5786870966165724
# 	  p = 0.5654218313981402
# t-test, Var=age
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.7034074648650914
# 	  p = 0.484739300158584
# t-test, Var=age
# 	 Comparing SCZ vs ADHD:
# 	  t = 1.4679702041475802
# 	  p = 0.14748216337505204
# t-test, Var=age
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.9109659157247262
# 	  p = 0.3656290614691081
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 4.262
# 	 p = 0.039
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 0.018
# 	 p = 0.8932
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 0.022
# 	 p = 0.8818
# Chi-square test, Var=sex
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 2.316
# 	 p = 0.128
# Chi-square test, Var=sex
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 2.032
# 	 p = 0.154
# Chi-square test, Var=sex
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.038
# 	 p = 0.8448
# Chi-square test, Var=site
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 19.007
# 	 p = 0.0
# Chi-square test, Var=site
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 14.936
# 	 p = 0.0001
# Chi-square test, Var=site
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 11.559
# 	 p = 0.0007
# Chi-square test, Var=site
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 0.356
# 	 p = 0.5508
# Chi-square test, Var=site
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 0.567
# 	 p = 0.4515
# Chi-square test, Var=site
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.0
# 	 p = 0.9849
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.442303002829502
# 	  p = 0.019626025508503498
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -2.258748339907665
# 	  p = 0.027797181876842134
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.9534163833201121
# 	  p = 0.053321260337162404
# t-test, Var=mean_FD
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.2505678342432759
# 	  p = 0.8029991323882495
# t-test, Var=mean_FD
# 	 Comparing SCZ vs ADHD:
# 	  t = 3.5271927030059476
# 	  p = 0.0012316630211398267
# t-test, Var=mean_FD
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 3.4119924592602464
# 	  p = 0.001257557384972848
# t-test, Var=edu_years
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.6244262443977915
# 	  p = 6.800317191589907e-08
# t-test, Var=edu_years
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.906137308731681
# 	  p = 0.06115357454861343
# t-test, Var=edu_years
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.4981825682277716
# 	  p = 0.14015435108031477
# t-test, Var=edu_years
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.049296647030169
# 	  p = 0.0001518266036109289
# t-test, Var=edu_years
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.201825266860203
# 	  p = 9.386234059041186e-05
# t-test, Var=edu_years
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.2680338565012812
# 	  p = 0.7894544137636152
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.446727477116673
# 	  p = 1.965408385406749e-07
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.6325610834512658
# 	  p = 0.10758167710665886
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.4432603847867673
# 	  p = 0.659275276288654
# t-test, Var=wais_mr
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.4146530412389025
# 	  p = 5.001057453504902e-05
# t-test, Var=wais_mr
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.377295581897397
# 	  p = 2.0881030055928445e-06
# t-test, Var=wais_mr
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -1.0051781076528263
# 	  p = 0.3181780604070237
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs SCZ:
# 	  t = 5.785231317205168
# 	  p = 6.058933078202284e-07
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 2.737932857986692
# 	  p = 0.007715142723181169
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs ADHD:
# 	  t = 2.251725784778009
# 	  p = 0.027823021498485492
# t-test, Var=wais_lns
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -2.81920557850818
# 	  p = 0.0065412118722917145
# t-test, Var=wais_lns
# 	 Comparing SCZ vs ADHD:
# 	  t = -3.16336317022555
# 	  p = 0.0025116490063280296
# t-test, Var=wais_lns
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.38666853645194205
# 	  p = 0.7001535007276538
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs SCZ:
# 	  t = 7.339918898508912
# 	  p = 7.161633960019395e-09
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.5974031767484264
# 	  p = 0.5524441413866883
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.7316875795426322
# 	  p = 0.4678364847606108
# t-test, Var=wais_voc
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -5.4973205803646445
# 	  p = 8.161490230718169e-07
# t-test, Var=wais_voc
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.157105817803591
# 	  p = 3.136340384374632e-06
# t-test, Var=wais_voc
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.13892919240079316
# 	  p = 0.8899041299142818
#
# Means:
#                  age       sex      site   mean_FD  edu_years    wais_mr  \
# diagnosis
# ADHD       32.529412  0.529412  0.500000  0.111921  14.617647  20.323529
# BIPOLAR    34.600000  0.525000  0.475000  0.180193  14.500000  19.325000
# CONTROL    31.388350  0.495146  0.815534  0.134289  15.155340  20.669903
# SCZ        36.185185  0.740741  0.370370  0.186985  12.666667  14.037037
#
#             wais_lns   wais_voc
# diagnosis
# ADHD       19.941176  42.470588
# BIPOLAR    19.700000  42.800000
# CONTROL    21.135922  43.883495
# SCZ        17.851852  29.851852
#
# Std:
#                  age       sex      site   mean_FD  edu_years   wais_mr  \
# diagnosis
# ADHD       10.340375  0.506640  0.507519  0.044878   1.858881  3.952142
# BIPOLAR     8.992304  0.505736  0.505736  0.116814   1.908147  4.593125
# CONTROL     8.749491  0.502421  0.389760  0.086043   1.673070  3.946675
# SCZ         9.085225  0.446576  0.492103  0.103097   1.754116  4.949604
#
#            wais_lns   wais_voc
# diagnosis
# ADHD       2.593011  10.151087
# BIPOLAR    2.766095  10.180927
# CONTROL    2.937414   8.479850
# SCZ        2.537469   8.934392

# %%
testttt_results = all_groups_stats(exclude_final, labels=labels)
print(testttt_results)
# Out:
# t-test, Var=age
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.4606197838759827
# 	  p = 0.018332359470566856
# t-test, Var=age
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.9315155450354025
# 	  p = 0.05750580657571162
# t-test, Var=age
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.5786870966165724
# 	  p = 0.5654218313981402
# t-test, Var=age
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.7034074648650914
# 	  p = 0.484739300158584
# t-test, Var=age
# 	 Comparing SCZ vs ADHD:
# 	  t = 1.4679702041475802
# 	  p = 0.14748216337505204
# t-test, Var=age
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.9109659157247262
# 	  p = 0.3656290614691081
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 4.262
# 	 p = 0.03897502
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 0.018
# 	 p = 0.89324963
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 0.022
# 	 p = 0.8817851
# Chi-square test, Var=sex
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 2.316
# 	 p = 0.12803089
# Chi-square test, Var=sex
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 2.032
# 	 p = 0.15397632
# Chi-square test, Var=sex
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.038
# 	 p = 0.84482701
# Chi-square test, Var=site
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 19.007
# 	 p = 1.303e-05
# Chi-square test, Var=site
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 14.936
# 	 p = 0.00011124
# Chi-square test, Var=site
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 11.559
# 	 p = 0.00067423
# Chi-square test, Var=site
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 0.356
# 	 p = 0.55084914
# Chi-square test, Var=site
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 0.567
# 	 p = 0.45148062
# Chi-square test, Var=site
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.0
# 	 p = 0.9849048
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.442303002829502
# 	  p = 0.019626025508503498
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -2.258748339907665
# 	  p = 0.027797181876842134
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.9534163833201121
# 	  p = 0.053321260337162404
# t-test, Var=mean_FD
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.2505678342432759
# 	  p = 0.8029991323882495
# t-test, Var=mean_FD
# 	 Comparing SCZ vs ADHD:
# 	  t = 3.5271927030059476
# 	  p = 0.0012316630211398267
# t-test, Var=mean_FD
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 3.4119924592602464
# 	  p = 0.001257557384972848
# t-test, Var=edu_years
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.6244262443977915
# 	  p = 6.800317191589907e-08
# t-test, Var=edu_years
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.906137308731681
# 	  p = 0.06115357454861343
# t-test, Var=edu_years
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.4981825682277716
# 	  p = 0.14015435108031477
# t-test, Var=edu_years
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.049296647030169
# 	  p = 0.0001518266036109289
# t-test, Var=edu_years
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.201825266860203
# 	  p = 9.386234059041186e-05
# t-test, Var=edu_years
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.2680338565012812
# 	  p = 0.7894544137636152
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.446727477116673
# 	  p = 1.965408385406749e-07
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.6325610834512658
# 	  p = 0.10758167710665886
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.4432603847867673
# 	  p = 0.659275276288654
# t-test, Var=wais_mr
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.4146530412389025
# 	  p = 5.001057453504902e-05
# t-test, Var=wais_mr
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.377295581897397
# 	  p = 2.0881030055928445e-06
# t-test, Var=wais_mr
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -1.0051781076528263
# 	  p = 0.3181780604070237
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs SCZ:
# 	  t = 5.785231317205168
# 	  p = 6.058933078202284e-07
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 2.737932857986692
# 	  p = 0.007715142723181169
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs ADHD:
# 	  t = 2.251725784778009
# 	  p = 0.027823021498485492
# t-test, Var=wais_lns
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -2.81920557850818
# 	  p = 0.0065412118722917145
# t-test, Var=wais_lns
# 	 Comparing SCZ vs ADHD:
# 	  t = -3.16336317022555
# 	  p = 0.0025116490063280296
# t-test, Var=wais_lns
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.38666853645194205
# 	  p = 0.7001535007276538
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs SCZ:
# 	  t = 7.339918898508912
# 	  p = 7.161633960019395e-09
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.5974031767484264
# 	  p = 0.5524441413866883
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.7316875795426322
# 	  p = 0.4678364847606108
# t-test, Var=wais_voc
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -5.4973205803646445
# 	  p = 8.161490230718169e-07
# t-test, Var=wais_voc
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.157105817803591
# 	  p = 3.136340384374632e-06
# t-test, Var=wais_voc
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.13892919240079316
# 	  p = 0.8899041299142818
#
# Means:
#                  age       sex      site   mean_FD  edu_years    wais_mr  \
# diagnosis
# ADHD       32.529412  0.529412  0.500000  0.111921  14.617647  20.323529
# BIPOLAR    34.600000  0.525000  0.475000  0.180193  14.500000  19.325000
# CONTROL    31.388350  0.495146  0.815534  0.134289  15.155340  20.669903
# SCZ        36.185185  0.740741  0.370370  0.186985  12.666667  14.037037
#
#             wais_lns   wais_voc
# diagnosis
# ADHD       19.941176  42.470588
# BIPOLAR    19.700000  42.800000
# CONTROL    21.135922  43.883495
# SCZ        17.851852  29.851852
#
# Std:
#                  age       sex      site   mean_FD  edu_years   wais_mr  \
# diagnosis
# ADHD       10.340375  0.506640  0.507519  0.044878   1.858881  3.952142
# BIPOLAR     8.992304  0.505736  0.505736  0.116814   1.908147  4.593125
# CONTROL     8.749491  0.502421  0.389760  0.086043   1.673070  3.946675
# SCZ         9.085225  0.446576  0.492103  0.103097   1.754116  4.949604
#
#            wais_lns   wais_voc
# diagnosis
# ADHD       2.593011  10.151087
# BIPOLAR    2.766095  10.180927
# CONTROL    2.937414   8.479850
# SCZ        2.537469   8.934392

# %% [markdown]
# Exclude scap outliers based on accuracy

# %%
try_df = pd.read_csv('/home/gabridele/Desktop/preproc_psych/subj_final.tsv', sep='\t')

# %%
def load_scan_behaviour(subj_list,task_list,group_index):
    '''
    Loads in-scanner task behaviour. Currently only coded up for the 'SCAP' task.
    For in-depth explanation of the tasks and the conditions modelled in the GLM
    see the postFmriprepPipelines.py script which does the GLM.
    
    returns: 
    - accuracy, 
    - reaction_time, 
    - accuracy_all, 
    - reaction_time_all, 
    - labels
    '''
    BIDS_DIR = "/home/gabridele/Desktop/psych_dataset/"
    accuracy_all = {}
    reaction_time_all = {}
    accuracy = {}
    reaction_time = {}
    labels = {}

    for task in task_list:
        if task=='scap':
            # 12 conditions - each cognitive load and each delay
            task_label = ['load1-delay1.5','load1-delay3','load1-delay4.5',
                     'load3-delay1.5','load3-delay3','load3-delay4.5',
                     'load5-delay1.5','load5-delay3','load5-delay4.5',
                     'load7-delay1.5','load7-delay3','load7-delay4.5']

            raw_acc = np.zeros((4,12,len(subj_list))) # trial x condition x subject
            raw_rt = raw_acc.copy()

            for i,subj in enumerate(subj_list):
                # get task information
                df_task = pd.read_csv(BIDS_DIR + str(subj) + '/func/' + str(subj) + '_task-' + task + '_events.tsv', sep='\t', header=0)

                for trial in range(1,13):
                    #accuracy
                    acc = df_task['ResponseAccuracy'].values[df_task['trial_type']==trial]=='CORRECT'
                    acc = acc.astype(int)
                    raw_acc[:,trial-1,i] = acc
                    #rt
                    rt = df_task['ReactionTime'].values[df_task['trial_type']==trial]
                    raw_rt[:,trial-1,i] = rt

        # put in a task list
        accuracy_all[task] = raw_acc
        reaction_time_all[task] = raw_rt
        labels[task] = task_label

        # put in a list with groups
        accuracy[task] = {}
        accuracy[task]['CONTROL'] = raw_acc[:,:,group_index=='CONTROL']
        accuracy[task]['SCZ'] = raw_acc[:,:,group_index=='SCZ']
        accuracy[task]['BIPOLAR'] = raw_acc[:,:,group_index=='BIPOLAR']
        accuracy[task]['ADHD'] = raw_acc[:,:,group_index=='ADHD']

        reaction_time[task] = {}
        reaction_time[task]['CONTROL'] = raw_rt[:,:,group_index=='CONTROL']
        reaction_time[task]['SCZ'] = raw_rt[:,:,group_index=='SCZ']
        reaction_time[task]['BIPOLAR'] = raw_rt[:,:,group_index=='BIPOLAR']
        reaction_time[task]['ADHD'] = raw_rt[:,:,group_index=='ADHD']
    return accuracy, reaction_time, accuracy_all, reaction_time_all, labels

# %%
import matplotlib.pyplot as plt
from scipy.stats import zscore
accuracy,reaction_time,_,_,task_labels = load_scan_behaviour(try_df['Sub_ID'],['scap'],try_df['diagnosis'].values)
hc_acc = np.mean(np.mean(accuracy['scap']['CONTROL'],axis=0),axis=0)
sz_acc = np.mean(np.mean(accuracy['scap']['SCZ'],axis=0),axis=0)
bplr_acc = np.mean(np.mean(accuracy['scap']['BIPOLAR'],axis=0),axis=0)
adhd_acc = np.mean(np.mean(accuracy['scap']['ADHD'],axis=0),axis=0)

idx = zscore(hc_acc) < -4
bad_subjs = try_df['Sub_ID'][try_df['diagnosis']=='CONTROL'][idx]
print('Poor subjs:',bad_subjs)
print('Odd HC participant scored:',hc_acc[idx]*100,'%')
print('Odd HC participant scored:',zscore(hc_acc)[idx],'(zscore)')

#plot the histograms
plt.hist(zscore(hc_acc))
plt.show()
plt.hist(zscore(sz_acc))
plt.show()
plt.hist(zscore(bplr_acc))
plt.show()
plt.hist(zscore(adhd_acc))
plt.show()
# Out:
# Poor subjs: 52    sub-10680
# 65    sub-10788
# Name: Sub_ID, dtype: object
# Odd HC participant scored: [25.   31.25] %
# Odd HC participant scored: [-5.05063257 -4.52533959] (zscore)

# %%
print(try_df['diagnosis'].value_counts())
# Out:
# diagnosis
# CONTROL    103
# BIPOLAR     40
# ADHD        34
# SCZ         27
# Name: count, dtype: int64

# %%
print(bad_subjs)
# Out:
# 52    sub-10680
# 65    sub-10788
# Name: Sub_ID, dtype: object

# %%
print(try_df.loc[67])
# Out:
# Sub_ID                 sub-10855
# diagnosis                CONTROL
# reason                       NaN
# Hearne base            sub-10855
# Hearne site control    sub-10855
# Notes                        NaN
# mean_FD                 0.108655
# age                           47
# sex                            1
# site                           1
# edu_years                     14
# wais_mr                       10
# wais_lns                      15
# wais_voc                      34
# Name: 67, dtype: object

# %%
# # drop the subject

try_df = try_df.drop(bad_subjs.index)

# print average demos
print(try_df['diagnosis'].value_counts())
print(try_df.groupby(['diagnosis'])[['age', 'sex', 'site']].mean())
# Out:
# diagnosis
# CONTROL    101
# BIPOLAR     40
# ADHD        34
# SCZ         27
# Name: count, dtype: int64
#                  age       sex      site
# diagnosis
# ADHD       32.529412  0.529412  0.500000
# BIPOLAR    34.600000  0.525000  0.475000
# CONTROL    31.445545  0.504950  0.811881
# SCZ        36.185185  0.740741  0.370370

# %%
test__results = all_groups_stats(exclude_final, labels=labels)
print(test__results)
# Out:
# t-test, Var=age
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.4028718140598975
# 	  p = 0.02096999545510127
# 	  Cohen's d = 0.53028746
# t-test, Var=age
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.864953925247792
# 	  p = 0.06634162466132437
# 	  Cohen's d = 0.35189094
# t-test, Var=age
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.5298928810447026
# 	  p = 0.5985173668515057
# 	  Cohen's d = 0.11380729
# t-test, Var=age
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.7034074648650914
# 	  p = 0.484739300158584
# 	  Cohen's d = 0.17555456
# t-test, Var=age
# 	 Comparing SCZ vs ADHD:
# 	  t = 1.4679702041475802
# 	  p = 0.14748216337505204
# 	  Cohen's d = 0.37276898
# t-test, Var=age
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.9109659157247262
# 	  p = 0.3656290614691081
# 	  Cohen's d = 0.21493367
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 3.703
# 	 p = 0.05430361
# 	 Cramer's V = 0.17076349
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 0.001
# 	 p = 0.97866947
# 	 Cramer's V = 0.00225969
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 0.0
# 	 p = 0.99763478
# 	 Cramer's V = 0.00025608
# Chi-square test, Var=sex
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 2.316
# 	 p = 0.12803089
# 	 Cramer's V = 0.18593126
# Chi-square test, Var=sex
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 2.032
# 	 p = 0.15397632
# 	 Cramer's V = 0.18253271
# Chi-square test, Var=sex
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.038
# 	 p = 0.84482701
# 	 Cramer's V = 0.02275233
# Chi-square test, Var=site
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 18.124
# 	 p = 2.07e-05
# 	 Cramer's V = 0.37776285
# Chi-square test, Var=site
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 14.113
# 	 p = 0.00017216
# 	 Cramer's V = 0.3175
# Chi-square test, Var=site
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 10.883
# 	 p = 0.00097073
# 	 Cramer's V = 0.28497936
# Chi-square test, Var=site
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 0.356
# 	 p = 0.55084914
# 	 Cramer's V = 0.07287263
# Chi-square test, Var=site
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 0.567
# 	 p = 0.45148062
# 	 Cramer's V = 0.09640523
# Chi-square test, Var=site
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.0
# 	 p = 0.9849048
# 	 Cramer's V = 0.00219942
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.440645077074827
# 	  p = 0.019628554412535984
# 	  Cohen's d = 0.58420624
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -2.2571712502014707
# 	  p = 0.027842257069834776
# 	  Cohen's d = 0.47849626
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.9128309677055382
# 	  p = 0.058352561068268353
# 	  Cohen's d = 0.28278006
# t-test, Var=mean_FD
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.2505678342432759
# 	  p = 0.8029991323882495
# 	  Cohen's d = 0.06090038
# t-test, Var=mean_FD
# 	 Comparing SCZ vs ADHD:
# 	  t = 3.5271927030059476
# 	  p = 0.0012316630211398267
# 	  Cohen's d = 0.98475136
# t-test, Var=mean_FD
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 3.4119924592602464
# 	  p = 0.001257557384972848
# 	  Cohen's d = 0.74872972
# t-test, Var=edu_years
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.488099728842787
# 	  p = 1.0133816265909457e-07
# 	  Cohen's d = 1.44824106
# t-test, Var=edu_years
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.7691699783876083
# 	  p = 0.08161820927767083
# 	  Cohen's d = 0.35058260
# t-test, Var=edu_years
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.368238043973959
# 	  p = 0.17709151335854825
# 	  Cohen's d = 0.28650471
# t-test, Var=edu_years
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.049296647030169
# 	  p = 0.0001518266036109289
# 	  Cohen's d = 0.99202274
# t-test, Var=edu_years
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.201825266860203
# 	  p = 9.386234059041186e-05
# 	  Cohen's d = 1.07583366
# t-test, Var=edu_years
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.2680338565012812
# 	  p = 0.7894544137636152
# 	  Cohen's d = 0.06238819
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs SCZ:
# 	  t = 6.402500653624528
# 	  p = 2.1080991685761483e-07
# 	  Cohen's d = 1.57070399
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.598720035622143
# 	  p = 0.11482013549587139
# 	  Cohen's d = 0.31762294
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.4149981984535671
# 	  p = 0.6796856428982161
# 	  Cohen's d = 0.08196395
# t-test, Var=wais_mr
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.4146530412389025
# 	  p = 5.001057453504902e-05
# 	  Cohen's d = 1.11585466
# t-test, Var=wais_mr
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.377295581897397
# 	  p = 2.0881030055928445e-06
# 	  Cohen's d = 1.42243357
# t-test, Var=wais_mr
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -1.0051781076528263
# 	  p = 0.3181780604070237
# 	  Cohen's d = 0.23161355
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs SCZ:
# 	  t = 5.634384110392168
# 	  p = 1.021013612574823e-06
# 	  Cohen's d = 1.13289484
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 2.5743762678216138
# 	  p = 0.012014825210812409
# 	  Cohen's d = 0.47237016
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs ADHD:
# 	  t = 2.090007010620729
# 	  p = 0.040653987747961466
# 	  Cohen's d = 0.39302847
# t-test, Var=wais_lns
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -2.81920557850818
# 	  p = 0.0065412118722917145
# 	  Cohen's d = 0.69038328
# t-test, Var=wais_lns
# 	 Comparing SCZ vs ADHD:
# 	  t = -3.16336317022555
# 	  p = 0.0025116490063280296
# 	  Cohen's d = 0.81338365
# t-test, Var=wais_lns
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.38666853645194205
# 	  p = 0.7001535007276538
# 	  Cohen's d = 0.08971842
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs SCZ:
# 	  t = 7.212647926342776
# 	  p = 9.940278270183247e-09
# 	  Cohen's d = 1.60875663
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.48875527979374545
# 	  p = 0.6267407422698867
# 	  Cohen's d = 0.09872215
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.6292563982025035
# 	  p = 0.5320620959388969
# 	  Cohen's d = 0.13624499
# t-test, Var=wais_voc
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -5.4973205803646445
# 	  p = 8.161490230718169e-07
# 	  Cohen's d = 1.33464707
# t-test, Var=wais_voc
# 	 Comparing SCZ vs ADHD:
# 	  t = -5.157105817803591
# 	  p = 3.136340384374632e-06
# 	  Cohen's d = 1.30983018
# t-test, Var=wais_voc
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.13892919240079316
# 	  p = 0.8899041299142818
# 	  Cohen's d = 0.03239926
#
# Means:
#                  age       sex     site   mean_FD  edu_years    wais_mr  \
# diagnosis
# ADHD       32.529412  0.529412  0.50000  0.111921  14.617647  20.323529
# BIPOLAR    34.600000  0.525000  0.47500  0.180193  14.500000  19.325000
# CONTROL    31.480000  0.510000  0.81000  0.134122  15.110000  20.650000
# SCZ        36.185185  0.740741  0.37037  0.186985  12.666667  14.037037
#
#             wais_lns   wais_voc
# diagnosis
# ADHD       19.941176  42.470588
# BIPOLAR    19.700000  42.800000
# CONTROL    21.050000  43.690000
# SCZ        17.851852  29.851852
#
# Std:
#                  age       sex      site   mean_FD  edu_years   wais_mr  \
# diagnosis
# ADHD       10.340375  0.506640  0.507519  0.044878   1.858881  3.952142
# BIPOLAR     8.992304  0.505736  0.505736  0.116814   1.908147  4.593125
# CONTROL     8.816284  0.502418  0.394277  0.086872   1.669059  3.993366
# SCZ         9.085225  0.446576  0.492103  0.103097   1.754116  4.949604
#
#            wais_lns   wais_voc
# diagnosis
# ADHD       2.593011  10.151087
# BIPOLAR    2.766095  10.180927
# CONTROL    2.893305   8.512255
# SCZ        2.537469   8.934392

# %% [markdown]
# Group by site (0 vs 1) and perform stats

# %%
try_df0 = try_df[try_df['site'] == 0]
try_df1 = try_df[try_df['site'] == 1]

try_df0_grouped = try_df0.groupby(['diagnosis'])[labels].mean()
try_df1_grouped = try_df1.groupby(['diagnosis'])[labels].mean()
print(try_df0)
print(try_df1)
# Out:
#         Sub_ID diagnosis  reason Hearne base Hearne site control Notes  \
# 84   sub-11061   CONTROL     NaN   sub-11061           sub-11061   NaN
# 85   sub-11062   CONTROL     NaN   sub-11062           sub-11062   NaN
# 86   sub-11066   CONTROL     NaN   sub-11066           sub-11066   NaN
# 87   sub-11067   CONTROL     NaN         NaN                 NaN   NaN
# 88   sub-11068   CONTROL     NaN   sub-11068           sub-11068   NaN
# ..         ...       ...     ...         ...                 ...   ...
# 199  sub-70079      ADHD     NaN   sub-70079           sub-70079   NaN
# 200  sub-70080      ADHD     NaN   sub-70080           sub-70080   NaN
# 201  sub-70081      ADHD     NaN   sub-70081           sub-70081   NaN
# 202  sub-70083      ADHD     NaN   sub-70083           sub-70083   NaN
# 203  sub-70086      ADHD     NaN   sub-70086           sub-70086   NaN
#
#       mean_FD  age  sex  site  edu_years  wais_mr  wais_lns  wais_voc
# 84   0.228207   45    0     0         14       21        22        55
# 85   0.430635   49    0     0         14        9        21        47
# 86   0.110426   37    1     0         12       23        26        41
# 87   0.068648   23    0     0         16       20        24        53
# 88   0.116280   39    1     0         16       19        21        56
# ..        ...  ...  ...   ...        ...      ...       ...       ...
# 199  0.176860   21    1     0         15       16        22        52
# 200  0.164081   48    1     0         13       17        20        51
# 201  0.095929   50    1     0         12       18        22        42
# 202  0.200959   46    0     0         16       19        17        29
# 203  0.164218   48    1     0         14       19        21        56
#
# [74 rows x 14 columns]
#         Sub_ID diagnosis  reason Hearne base Hearne site control Notes  \
# 0    sub-10159   CONTROL     NaN   sub-10159                 NaN   NaN
# 1    sub-10171   CONTROL     NaN   sub-10171                 NaN   NaN
# 2    sub-10189   CONTROL     NaN   sub-10189           sub-10189   NaN
# 3    sub-10206   CONTROL     NaN         NaN                 NaN   NaN
# 4    sub-10217   CONTROL     NaN   sub-10217           sub-10217   NaN
# ..         ...       ...     ...         ...                 ...   ...
# 182  sub-70040      ADHD     NaN   sub-70040           sub-70040   NaN
# 183  sub-70046      ADHD     NaN   sub-70046           sub-70046   NaN
# 184  sub-70048      ADHD     NaN         NaN                 NaN   NaN
# 185  sub-70049      ADHD     NaN   sub-70049           sub-70049   NaN
# 186  sub-70052      ADHD     NaN   sub-70052           sub-70052   NaN
#
#       mean_FD  age  sex  site  edu_years  wais_mr  wais_lns  wais_voc
# 0    0.177901   30    0     1         16       21        19        49
# 1    0.174510   24    1     1         16       23        28        53
# 2    0.142876   49    1     1         16       22        18        48
# 3    0.077702   21    1     1         13       20        14        35
# 4    0.064066   33    0     1         16       20        22        46
# ..        ...  ...  ...   ...        ...      ...       ...       ...
# 182  0.133162   30    0     1         13       24        21        44
# 183  0.070015   32    1     1         12       24        22        39
# 184  0.057510   23    0     1         12       18        16        28
# 185  0.073826   25    0     1         18       26        18        43
# 186  0.151544   27    0     1         14       24        23        51
#
# [128 rows x 14 columns]

# %%
print(try_df0['diagnosis'].value_counts())
# Out:
# diagnosis
# BIPOLAR    21
# CONTROL    19
# SCZ        17
# ADHD       17
# Name: count, dtype: int64

# %%
print(try_df1['diagnosis'].value_counts())
# Out:
# diagnosis
# CONTROL    82
# BIPOLAR    19
# ADHD       17
# SCZ        10
# Name: count, dtype: int64

# %%
labels_site = ['age','sex','edu_years', 'mean_FD', 'wais_mr','wais_lns','wais_voc']
site0_test = all_groups_stats(try_df0, labels=labels_site)
print(site0_test)
# Out:
# t-test, Var=age
# 	 Comparing CONTROL vs SCZ:
# 	  t = -1.5660076894447186
# 	  p = 0.12661112860288837
# 	  Cohen's d = 0.51886642
# t-test, Var=age
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.6061751611251534
# 	  p = 0.11685614026838083
# 	  Cohen's d = 0.51120500
# t-test, Var=age
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.6288173987024883
# 	  p = 0.5340302211655351
# 	  Cohen's d = 0.21211253
# t-test, Var=age
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.012642856081155564
# 	  p = 0.9899849478288127
# 	  Cohen's d = 0.00411076
# t-test, Var=age
# 	 Comparing SCZ vs ADHD:
# 	  t = 0.7114695712708379
# 	  p = 0.4824269379762637
# 	  Cohen's d = 0.24403205
# t-test, Var=age
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.7187016474106231
# 	  p = 0.4780503996006582
# 	  Cohen's d = 0.24162278
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 4.539
# 	 p = 0.03312586
# 	 Cramer's V = 0.35509242
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 1.54
# 	 p = 0.21458593
# 	 Cramer's V = 0.19622781
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 1.907
# 	 p = 0.16726621
# 	 Cramer's V = 0.23017358
# Chi-square test, Var=sex
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 0.52
# 	 p = 0.47065909
# 	 Cramer's V = 0.11702768
# Chi-square test, Var=sex
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 0.163
# 	 p = 0.68598935
# 	 Cramer's V = 0.06933752
# Chi-square test, Var=sex
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.009
# 	 p = 0.92641768
# 	 Cramer's V = 0.01498161
# t-test, Var=edu_years
# 	 Comparing CONTROL vs SCZ:
# 	  t = 5.071784429729384
# 	  p = 1.4057191082396485e-05
# 	  Cohen's d = 1.68938011
# t-test, Var=edu_years
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.6311570679428622
# 	  p = 0.11122155254581735
# 	  Cohen's d = 0.51670003
# t-test, Var=edu_years
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.3864662831770329
# 	  p = 0.701734820493218
# 	  Cohen's d = 0.13018891
# t-test, Var=edu_years
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -3.5992810398240707
# 	  p = 0.000983100265745229
# 	  Cohen's d = 1.17039510
# t-test, Var=edu_years
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.128132102340949
# 	  p = 0.00025774393727121057
# 	  Cohen's d = 1.41593763
# t-test, Var=edu_years
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -1.0445517771539905
# 	  p = 0.30419220810143727
# 	  Cohen's d = 0.34697667
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs SCZ:
# 	  t = -2.643751837563909
# 	  p = 0.012892484864135353
# 	  Cohen's d = 0.89523327
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.7216986600282154
# 	  p = 0.09335921709676732
# 	  Cohen's d = 0.53920279
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.1580491779240149
# 	  p = 0.8755829351697251
# 	  Cohen's d = 0.05100790
# t-test, Var=mean_FD
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 1.000057317065278
# 	  p = 0.3243862521828572
# 	  Cohen's d = 0.32758122
# t-test, Var=mean_FD
# 	 Comparing SCZ vs ADHD:
# 	  t = 3.1752903724253367
# 	  p = 0.004591498557145842
# 	  Cohen's d = 1.08911561
# t-test, Var=mean_FD
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 2.19328513344182
# 	  p = 0.03688320430381778
# 	  Cohen's d = 0.66229489
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs SCZ:
# 	  t = 4.329037114213877
# 	  p = 0.00014915766141291808
# 	  Cohen's d = 1.46409394
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.7075087313328404
# 	  p = 0.4835852353625383
# 	  Cohen's d = 0.22357718
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.37111041567244346
# 	  p = 0.7128588720816578
# 	  Cohen's d = 0.12293737
# t-test, Var=wais_mr
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -3.7476853217884156
# 	  p = 0.0007335288088217953
# 	  Cohen's d = 1.24812416
# t-test, Var=wais_mr
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.13889962836414
# 	  p = 0.00028168129091846894
# 	  Cohen's d = 1.41963086
# t-test, Var=wais_mr
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.3623635002315609
# 	  p = 0.7192029060543697
# 	  Cohen's d = 0.11603383
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs SCZ:
# 	  t = 4.094695629957579
# 	  p = 0.00025237397615022057
# 	  Cohen's d = 1.36823788
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 2.194549880269078
# 	  p = 0.03447546293717416
# 	  Cohen's d = 0.69558290
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.3574118508370159
# 	  p = 0.1837677995316147
# 	  Cohen's d = 0.45384273
# t-test, Var=wais_lns
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -2.1164024944398725
# 	  p = 0.04174955053807329
# 	  Cohen's d = 0.69320690
# t-test, Var=wais_lns
# 	 Comparing SCZ vs ADHD:
# 	  t = -2.6240088166844386
# 	  p = 0.013207389958641827
# 	  Cohen's d = 0.90002760
# t-test, Var=wais_lns
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.6969018139084042
# 	  p = 0.4906499327374295
# 	  Cohen's d = 0.22851554
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs SCZ:
# 	  t = 4.462796261299076
# 	  p = 8.540794949168276e-05
# 	  Cohen's d = 1.48711754
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.7052692853676835
# 	  p = 0.4849647507247832
# 	  Cohen's d = 0.22134656
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.049455312630654794
# 	  p = 0.9608480441694196
# 	  Cohen's d = 0.01648503
# t-test, Var=wais_voc
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -3.487686721809917
# 	  p = 0.001303097032719137
# 	  Cohen's d = 1.11314030
# t-test, Var=wais_voc
# 	 Comparing SCZ vs ADHD:
# 	  t = -4.449089457289256
# 	  p = 9.772599088081612e-05
# 	  Cohen's d = 1.52602509
# t-test, Var=wais_voc
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -0.742768867217576
# 	  p = 0.4624425424535824
# 	  Cohen's d = 0.23720176
#
# Means:
#                  age       sex  edu_years   mean_FD    wais_mr   wais_lns  \
# diagnosis
# ADHD       32.823529  0.705882  14.764706  0.120052  20.117647  19.823529
# BIPOLAR    35.142857  0.666667  14.142857  0.176090  19.619048  19.238095
# CONTROL    30.684211  0.421053  15.000000  0.123584  20.631579  21.000000
# SCZ        35.176471  0.823529  12.235294  0.211620  13.294118  17.470588
#
#             wais_voc
# diagnosis
# ADHD       43.529412
# BIPOLAR    40.952381
# CONTROL    43.368421
# SCZ        28.882353
#
# Std:
#                  age       sex  edu_years   mean_FD   wais_mr  wais_lns  \
# diagnosis
# ADHD       11.018367  0.469668   1.953504  0.043460  3.871084  2.627625
# BIPOLAR     8.290270  0.483046   1.651839  0.106657  4.609514  2.508082
# CONTROL     9.177585  0.507257   1.666667  0.085899  4.437348  2.560382
# SCZ         8.033020  0.392953   1.601929  0.110674  5.587539  2.600905
#
#             wais_voc
# diagnosis
# ADHD        9.624952
# BIPOLAR    11.762126
# CONTROL     9.889447
# SCZ         9.571327
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")

# %%
labels_site = ['age','sex','edu_years', 'mean_FD', 'wais_mr','wais_lns','wais_voc']
site1_test = all_groups_stats(try_df1, labels=labels_site)
print(site1_test)
# Out:
# t-test, Var=age
# 	 Comparing CONTROL vs SCZ:
# 	  t = -1.7558329384209337
# 	  p = 0.10830735446836101
# 	  Cohen's d = 0.69976354
# t-test, Var=age
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -0.9633354006313654
# 	  p = 0.34464647503534485
# 	  Cohen's d = 0.26548403
# t-test, Var=age
# 	 Comparing CONTROL vs ADHD:
# 	  t = -0.23607400090165853
# 	  p = 0.8156185655531135
# 	  Cohen's d = 0.06857232
# t-test, Var=age
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = 0.9453833723949935
# 	  p = 0.3577528079235065
# 	  Cohen's d = 0.38074207
# t-test, Var=age
# 	 Comparing SCZ vs ADHD:
# 	  t = 1.3474219866134234
# 	  p = 0.19491891334868464
# 	  Cohen's d = 0.55020915
# t-test, Var=age
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.5324707918783699
# 	  p = 0.5979115405569565
# 	  Cohen's d = 0.17780763
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs SCZ:
# 	 Chi2 = 0.014
# 	 p = 0.90705437
# 	 Cramer's V = 0.01217253
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs BIPOLAR:
# 	 Chi2 = 0.942
# 	 p = 0.33175049
# 	 Cramer's V = 0.09657771
# Chi-square test, Var=sex
# 	 Comparing CONTROL vs ADHD:
# 	 Chi2 = 1.041
# 	 p = 0.30760347
# 	 Cramer's V = 0.10254035
# Chi-square test, Var=sex
# 	 Comparing SCZ vs BIPOLAR:
# 	 Chi2 = 0.639
# 	 p = 0.42422025
# 	 Cramer's V = 0.14839305
# Chi-square test, Var=sex
# 	 Comparing SCZ vs ADHD:
# 	 Chi2 = 0.717
# 	 p = 0.39723141
# 	 Cramer's V = 0.16292366
# Chi-square test, Var=sex
# 	 Comparing BIPOLAR vs ADHD:
# 	 Chi2 = 0.063
# 	 p = 0.80182125
# 	 Cramer's V = 0.04183179
# t-test, Var=edu_years
# 	 Comparing CONTROL vs SCZ:
# 	  t = 2.863854053230799
# 	  p = 0.015547037253261623
# 	  Cohen's d = 1.03415335
# t-test, Var=edu_years
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 0.48135760137623546
# 	  p = 0.6347356385320436
# 	  Cohen's d = 0.14263868
# t-test, Var=edu_years
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.4211302119815759
# 	  p = 0.16927274080819762
# 	  Cohen's d = 0.39882063
# t-test, Var=edu_years
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -1.9679036129502854
# 	  p = 0.062428521674009606
# 	  Cohen's d = 0.73328123
# t-test, Var=edu_years
# 	 Comparing SCZ vs ADHD:
# 	  t = -1.470816791205886
# 	  p = 0.15793627009418854
# 	  Cohen's d = 0.58885678
# t-test, Var=edu_years
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.6459258750044181
# 	  p = 0.5226743860574772
# 	  Cohen's d = 0.21363134
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs SCZ:
# 	  t = -0.3505894995680716
# 	  p = 0.7319515787985905
# 	  Cohen's d = 0.10591114
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -1.55596733993985
# 	  p = 0.13405773921197647
# 	  Cohen's d = 0.50610744
# t-test, Var=mean_FD
# 	 Comparing CONTROL vs ADHD:
# 	  t = 2.1836297694381734
# 	  p = 0.03440228244311276
# 	  Cohen's d = 0.39392094
# t-test, Var=mean_FD
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -1.0326501669503578
# 	  p = 0.31109150752235076
# 	  Cohen's d = 0.34484604
# t-test, Var=mean_FD
# 	 Comparing SCZ vs ADHD:
# 	  t = 1.5521553165384694
# 	  p = 0.1447420454477769
# 	  Cohen's d = 0.70232512
# t-test, Var=mean_FD
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 2.5421850830298034
# 	  p = 0.018243154549156877
# 	  Cohen's d = 0.81186563
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs SCZ:
# 	  t = 4.490988033844326
# 	  p = 0.0007634224425934061
# 	  Cohen's d = 1.39281237
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.4451018937691211
# 	  p = 0.16131107953905718
# 	  Cohen's d = 0.41300194
# t-test, Var=wais_mr
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.1293946904554185
# 	  p = 0.8982080544178145
# 	  Cohen's d = 0.03593302
# t-test, Var=wais_mr
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -2.389533630745284
# 	  p = 0.025317049536627466
# 	  Cohen's d = 0.85460502
# t-test, Var=wais_mr
# 	 Comparing SCZ vs ADHD:
# 	  t = -3.4833547094232595
# 	  p = 0.0021569227265370535
# 	  Cohen's d = 1.33027262
# t-test, Var=wais_mr
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = -1.0405691217930388
# 	  p = 0.30541933842691005
# 	  Cohen's d = 0.34498418
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs SCZ:
# 	  t = 3.1686638598384143
# 	  p = 0.007519582756699912
# 	  Cohen's d = 0.88170903
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = 1.2170607727787053
# 	  p = 0.23399874714098173
# 	  Cohen's d = 0.30674899
# t-test, Var=wais_lns
# 	 Comparing CONTROL vs ADHD:
# 	  t = 1.505179529297896
# 	  p = 0.1444185668162037
# 	  Cohen's d = 0.36330064
# t-test, Var=wais_lns
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -1.661094135681648
# 	  p = 0.11069893249345225
# 	  Cohen's d = 0.60524187
# t-test, Var=wais_lns
# 	 Comparing SCZ vs ADHD:
# 	  t = -1.565723765257112
# 	  p = 0.1328086950793987
# 	  Cohen's d = 0.60965792
# t-test, Var=wais_lns
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 0.16126354154298148
# 	  p = 0.8728406462621243
# 	  Cohen's d = 0.05342927
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs SCZ:
# 	  t = 4.641935122036984
# 	  p = 0.0006342418708446477
# 	  Cohen's d = 1.50740874
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs BIPOLAR:
# 	  t = -0.46904737025724896
# 	  p = 0.6426879720981611
# 	  Cohen's d = 0.11623985
# t-test, Var=wais_voc
# 	 Comparing CONTROL vs ADHD:
# 	  t = 0.8907345481517362
# 	  p = 0.3836531192173003
# 	  Cohen's d = 0.28387530
# t-test, Var=wais_voc
# 	 Comparing SCZ vs BIPOLAR:
# 	  t = -4.310068763073111
# 	  p = 0.0004050756622413268
# 	  Cohen's d = 1.68589709
# t-test, Var=wais_voc
# 	 Comparing SCZ vs ADHD:
# 	  t = -2.7274373686964855
# 	  p = 0.011843489066967826
# 	  Cohen's d = 1.00193128
# t-test, Var=wais_voc
# 	 Comparing BIPOLAR vs ADHD:
# 	  t = 1.0740662405561978
# 	  p = 0.2916465749590618
# 	  Cohen's d = 0.36490531
#
# Means:
#                  age       sex  edu_years   mean_FD    wais_mr   wais_lns  \
# diagnosis
# ADHD       32.235294  0.352941  14.470588  0.103791  20.529412  20.058824
# BIPOLAR    34.000000  0.368421  14.894737  0.184727  19.000000  20.210526
# CONTROL    31.621951  0.524390  15.146341  0.135991  20.670732  21.146341
# SCZ        37.900000  0.600000  13.400000  0.145106  15.300000  18.500000
#
#             wais_voc
# diagnosis
# ADHD       41.411765
# BIPOLAR    44.842105
# CONTROL    43.890244
# SCZ        31.500000
#
# Std:
#                  age       sex  edu_years   mean_FD   wais_mr  wais_lns  \
# diagnosis
# ADHD        9.946918  0.492592   1.806850  0.046094  4.140013  2.633215
# BIPOLAR     9.905105  0.495595   2.131633  0.129939  4.678556  3.010702
# CONTROL     8.732853  0.502478   1.671267  0.087074  3.890650  3.059581
# SCZ        10.887812  0.516398   1.837873  0.076389  3.529243  2.415229
#
#             wais_voc
# diagnosis
# ADHD       10.840081
# BIPOLAR     7.904030
# CONTROL     8.250711
# SCZ         7.933753
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on observed frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
# /home/gabridele/miniconda3/envs/neuroimg/lib/python3.12/site-packages/pingouin/contingency.py:151: UserWarning: Low count on expected frequencies.
#   warnings.warn(f"Low count on {name} frequencies.")
